# %%
import pandas as pd
a=[1,7,2]
myvar=pd.Series(a,index=["x","y","z"])
print(myvar)
# Out:
# x    1
# y    7
# z    2
# dtype: int64

# %%
calories={"day1":420,"day2":380,"day3":390}
myvar = pd.Series(calories)
print(myvar)
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %%
import pandas as pd
data = {
"calories": [420, 380, 390],
"duration": [50, 40, 45]
}
myvar = pd.DataFrame(data)
print(myvar)
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45

# %%
import pandas as pd

data = {
    "calories": [420, 380, 390],
    "duration": [50, 40, 45]
}

myvar = pd.DataFrame(data)

print(myvar)

# Refer to row index 0
print(myvar.loc[0])
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# calories    420
# duration     50
# Name: 0, dtype: int64

# %%
data = {
"calories": [420, 380, 390],
"duration": [50, 40, 45]
}
df = pd.DataFrame(data, index = ["day1", "day2", "day3"])
print(df)


#refer to the named index:
print(df.loc["day2"])
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
# calories    380
# duration     40
# Name: day2, dtype: int64

# %%
df=pd.read_csv('/home/ksb/Downloads/data.csv')
print(df)
# Out:
#    Feature1  Feature2            Label
# 0       5.1       3.5      Iris-setosa
# 1       4.9       3.0      Iris-setosa
# 2       6.2       3.4  Iris-versicolor
# 3       5.9       3.0  Iris-versicolor
# 4       6.9       3.1  Iris-versicolor
# 5       5.5       2.3  Iris-versicolor
# 6       6.5       3.0   Iris-virginica
# 7       7.6       3.0   Iris-virginica
# 8       7.3       2.9   Iris-virginica
# 9       6.7       2.5   Iris-virginica

# %%
df=pd.read_csv('/home/ksb/Downloads/data.csv')
print(df.to_string())
# Out:
#    Feature1  Feature2            Label
# 0       5.1       3.5      Iris-setosa
# 1       4.9       3.0      Iris-setosa
# 2       6.2       3.4  Iris-versicolor
# 3       5.9       3.0  Iris-versicolor
# 4       6.9       3.1  Iris-versicolor
# 5       5.5       2.3  Iris-versicolor
# 6       6.5       3.0   Iris-virginica
# 7       7.6       3.0   Iris-virginica
# 8       7.3       2.9   Iris-virginica
# 9       6.7       2.5   Iris-virginica

# %%
import pandas as pd
print(pd.options.display.max_rows)
# Out:
# 60

# %%
pd.options.display.max_rows = 9999
df = pd.read_csv('/home/ksb/Downloads/data.csv')
print(df)
# Out:
#    Feature1  Feature2            Label
# 0       5.1       3.5      Iris-setosa
# 1       4.9       3.0      Iris-setosa
# 2       6.2       3.4  Iris-versicolor
# 3       5.9       3.0  Iris-versicolor
# 4       6.9       3.1  Iris-versicolor
# 5       5.5       2.3  Iris-versicolor
# 6       6.5       3.0   Iris-virginica
# 7       7.6       3.0   Iris-virginica
# 8       7.3       2.9   Iris-virginica
# 9       6.7       2.5   Iris-virginica

# %%
import pandas as pd
df = pd.read_csv('/home/ksb/Downloads/data.csv')
print(df.head(5))
# Out:
#    Feature1  Feature2            Label
# 0       5.1       3.5      Iris-setosa
# 1       4.9       3.0      Iris-setosa
# 2       6.2       3.4  Iris-versicolor
# 3       5.9       3.0  Iris-versicolor
# 4       6.9       3.1  Iris-versicolor

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Feature1  10 non-null     float64
#  1   Feature2  10 non-null     float64
#  2   Label     10 non-null     object
# dtypes: float64(2), object(1)
# memory usage: 372.0+ bytes
# None

# %%
import pandas as pd
df = pd.read_csv('/home/ksb/Downloads/data.csv')
new_df = df.dropna()
print(new_df.to_string())
# Out:
#    Feature1  Feature2            Label
# 0       5.1       3.5      Iris-setosa
# 1       4.9       3.0      Iris-setosa
# 2       6.2       3.4  Iris-versicolor
# 3       5.9       3.0  Iris-versicolor
# 4       6.9       3.1  Iris-versicolor
# 5       5.5       2.3  Iris-versicolor
# 6       6.5       3.0   Iris-virginica
# 7       7.6       3.0   Iris-virginica
# 8       7.3       2.9   Iris-virginica
# 9       6.7       2.5   Iris-virginica

# %%
import pandas as pd
df = pd.read_csv('/home/ksb/Downloads/data1.csv')
new_df = df.dropna()
print(new_df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110     130.0     409.1
# 1          60    117     145.0     479.0
# 2          60    103     135.0     340.0
# 3          45    109     175.0     282.4
# 4          45    117     148.0     406.0
# 5          60    102     127.0     300.0
# 6          60    110     136.0     374.0
# 7          45    104     134.0     253.3
# 8          30    109     133.0     195.1
# 9          60     98     124.0     269.0
# 10         60    103     147.0     329.3
# 11         60    100     120.0     250.7
# 12         60    106     128.0     345.3
# 13         60    104     132.0     379.3
# 14         60     98     123.0     275.0
# 15         60     98     120.0     215.2
# 16         60    100     120.0     300.0
# 18         60    103     123.0     323.0
# 19         45     97     125.0     243.0
# 20         60    108     131.0     364.2
# 21         45    100     119.0     282.0
# 22         60    130     101.0     300.0
# ...

# %%
import pandas as pd
df = pd.read_csv('/home/ksb/datascience/data.csv')
df["Calories"].fillna(130, inplace = True)
print(new_df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110     130.0     409.1
# 1          60    117     145.0     479.0
# 2          60    103     135.0     340.0
# 3          45    109     175.0     282.4
# 4          45    117     148.0     406.0
# 5          60    102     127.0     300.0
# 6          60    110     136.0     374.0
# 7          45    104     134.0     253.3
# 8          30    109     133.0     195.1
# 9          60     98     124.0     269.0
# 10         60    103     147.0     329.3
# 11         60    100     120.0     250.7
# 12         60    106     128.0     345.3
# 13         60    104     132.0     379.3
# 14         60     98     123.0     275.0
# 15         60     98     120.0     215.2
# 16         60    100     120.0     300.0
# 18         60    103     123.0     323.0
# 19         45     97     125.0     243.0
# 20         60    108     131.0     364.2
# 21         45    100     119.0     282.0
# 22         60    130     101.0     300.0
# ...

# %%
x = df["Calories"].mean()
df["Calories"].fillna(x, inplace = True)
print(new_df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110     130.0     409.1
# 1          60    117     145.0     479.0
# 2          60    103     135.0     340.0
# 3          45    109     175.0     282.4
# 4          45    117     148.0     406.0
# 5          60    102     127.0     300.0
# 6          60    110     136.0     374.0
# 7          45    104     134.0     253.3
# 8          30    109     133.0     195.1
# 9          60     98     124.0     269.0
# 10         60    103     147.0     329.3
# 11         60    100     120.0     250.7
# 12         60    106     128.0     345.3
# 13         60    104     132.0     379.3
# 14         60     98     123.0     275.0
# 15         60     98     120.0     215.2
# 16         60    100     120.0     300.0
# 18         60    103     123.0     323.0
# 19         45     97     125.0     243.0
# 20         60    108     131.0     364.2
# 21         45    100     119.0     282.0
# 22         60    130     101.0     300.0
# ...

# %%
x = df["Calories"].median()
df["Calories"].fillna(x, inplace = True)
print(new_df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110     130.0     409.1
# 1          60    117     145.0     479.0
# 2          60    103     135.0     340.0
# 3          45    109     175.0     282.4
# 4          45    117     148.0     406.0
# 5          60    102     127.0     300.0
# 6          60    110     136.0     374.0
# 7          45    104     134.0     253.3
# 8          30    109     133.0     195.1
# 9          60     98     124.0     269.0
# 10         60    103     147.0     329.3
# 11         60    100     120.0     250.7
# 12         60    106     128.0     345.3
# 13         60    104     132.0     379.3
# 14         60     98     123.0     275.0
# 15         60     98     120.0     215.2
# 16         60    100     120.0     300.0
# 18         60    103     123.0     323.0
# 19         45     97     125.0     243.0
# 20         60    108     131.0     364.2
# 21         45    100     119.0     282.0
# 22         60    130     101.0     300.0
# ...

# %%
df.drop_duplicates(inplace = True)
print(new_df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110     130.0     409.1
# 1          60    117     145.0     479.0
# 2          60    103     135.0     340.0
# 3          45    109     175.0     282.4
# 4          45    117     148.0     406.0
# 5          60    102     127.0     300.0
# 6          60    110     136.0     374.0
# 7          45    104     134.0     253.3
# 8          30    109     133.0     195.1
# 9          60     98     124.0     269.0
# 10         60    103     147.0     329.3
# 11         60    100     120.0     250.7
# 12         60    106     128.0     345.3
# 13         60    104     132.0     379.3
# 14         60     98     123.0     275.0
# 15         60     98     120.0     215.2
# 16         60    100     120.0     300.0
# 18         60    103     123.0     323.0
# 19         45     97     125.0     243.0
# 20         60    108     131.0     364.2
# 21         45    100     119.0     282.0
# 22         60    130     101.0     300.0
# ...

# %%
import matplotlib.pyplot as plt
df.plot()
plt.show()

# %%
df.plot(kind = 'scatter', x = 'Duration', y =
'Calories')
plt.show()

# %%
import pandas as pd
df = pd.read_csv('/home/ksb/Downloads/datadate.csv')
df['Date'] = pd.to_datetime(df['Date'])
print(df.to_string())
# Out:
#         Date     Name  Age       City  Salary
# 0 2026-01-05  Manisha   28  Kozhikode   35000
# 1 2026-01-12      Anu   25      Kochi   30000
# 2 2026-02-03     John   30     Kannur   42000
# 3 2026-02-18     Riya   27   Thrissur   38000
# 4 2026-03-10     Arun   32  Kozhikode   45000
# 5 2026-03-25    Meera   24      Kochi   28000
# 6 2026-04-08    David   29     Kannur   40000
# 7 2026-04-20     Neha   26   Thrissur   32000
# 8 2026-05-15    Rahul   31  Kozhikode   47000
# 9 2026-06-01    Sneha   23      Kochi   29000

# %%
import pandas as pd

df = pd.read_csv('/home/ksb/datascience/data.csv')

df.loc[2, 'Duration'] = 50

print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          50    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
import pandas as pd

df = pd.read_csv('/home/ksb/datascience/data.csv')

# Set Duration = 45 in row 7
df.loc[7, 'Duration'] = 45

# Change any Duration greater than 120 to 120
for x in df.index:
    if df.loc[x, "Duration"] > 120:
        df.loc[x, "Duration"] = 120

print(df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 17         45     90       112       NaN
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# ...

# %%
df.corr()
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.238237 -0.072727  0.820102
# Pulse    -0.238237  1.000000  0.786535  0.025121
# Maxpulse -0.072727  0.786535  1.000000  0.203813
# Calories  0.820102  0.025121  0.203813  1.000000
